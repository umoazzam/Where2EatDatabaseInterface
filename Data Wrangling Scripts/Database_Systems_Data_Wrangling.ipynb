# %%
import pandas as pd
import numpy as np
cuisine = pd.read_csv(r"C:\Users\sohan\OneDrive\Desktop\Database Systems Datasets\chefmozcuisine.csv")
accepts = pd.read_csv(r"C:\Users\sohan\OneDrive\Desktop\Database Systems Datasets\chefmozaccepts.csv")
hours = pd.read_csv(r"C:\Users\sohan\OneDrive\Desktop\Database Systems Datasets\chefmozhours4.csv")
parking = pd.read_csv(r"C:\Users\sohan\OneDrive\Desktop\Database Systems Datasets\chefmozparking.csv")

# %%
cuisine

# %%
parking
# Out:
#      placeID parking_lot
# 0     135111      public
# 1     135110        none
# 2     135109        none
# 3     135108        none
# 4     135107        none
# ..       ...         ...
# 697   132024      street
# 698   132023         fee
# 699   132023      public
# 700   132012      public
# 701   132012      street
#
# [702 rows x 2 columns]

# %%
pc = pd.merge(cuisine, parking, on='placeID')

# %%
test = pd.merge(pc, hours, on = 'placeID', how = 'left')

# %%
ids = test['placeID']
#ids.count(135111)
unique, counts = np.unique(ids, return_counts=True)
dictionary = dict(zip(unique, counts))
for x in unique:
    test.loc[test['placeID'] == x]
    
test.loc[test['placeID'] == unique[1]]
# Out:
#       placeID       Rcuisine parking_lot         hours                  days
# 2042   132023         French         fee  11:00-00:00;                  Sat;
# 2043   132023         French         fee  11:00-00:00;                  Sat;
# 2044   132023         French         fee  11:00-00:00;                  Sun;
# 2045   132023         French         fee  11:00-00:00;                  Sun;
# 2046   132023         French         fee  11:00-00:00;  Mon;Tue;Wed;Thu;Fri;
# 2047   132023         French         fee  11:00-00:00;  Mon;Tue;Wed;Thu;Fri;
# 2048   132023         French      public  11:00-00:00;                  Sat;
# 2049   132023         French      public  11:00-00:00;                  Sat;
# 2050   132023         French      public  11:00-00:00;                  Sun;
# 2051   132023         French      public  11:00-00:00;                  Sun;
# 2052   132023         French      public  11:00-00:00;  Mon;Tue;Wed;Thu;Fri;
# ...

# %%
pd.read_csv(r"C:\Users\sohan\OneDrive\Desktop\Database Systems Datasets\geoplaces2.csv", encoding='ISO-8859-1')
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# ..       ...        ...         ...
# 125   132866  22.141220 -100.931311
# 126   135072  22.149192 -101.002936
# 127   135109  18.921785  -99.235350
# 128   135019  18.875011  -99.159422
# 129   132877  22.135364 -100.934948
#
#                                         the_geom_meter  \
# 0    0101000020957F000088568DE356715AC138C0A525FC46...
# 1    0101000020957F00001AD016568C4858C1243261274BA5...
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3    0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4    0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# ..                                                 ...
# 125  0101000020957F000013871838EC4A58C1B5DF74F8E396...
# 126  0101000020957F0000E7B79B1DB94758C1D29BC363D8AA...
# ...

# %%
import chardet
with open(r"C:\Users\sohan\OneDrive\Desktop\Database Systems Datasets\geoplaces2.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.7292576630671638, 'language': ''}

# %%
Users = pd.read_csv(r"C:\Users\sohan\OneDrive\Desktop\users.csv")
Restaurants = pd.read_csv(r"C:\Users\sohan\OneDrive\Desktop\restaurants.csv")

# %%
u = Users['userID']
r = Restaurants['placeID']
records = {}
for x in u:
    visited = np.random.choice([1, 2, 3, 4, 5])
    records[x] = []
    for i in range(1, visited + 1):
        records[x].append(np.random.choice(r))
records
# Out:
# {'U1001': [132862, 135062],
#  'U1002': [135069, 132872, 135026],
#  'U1003': [135019, 132825],
#  'U1004': [135062, 132885],
#  'U1005': [135062, 132594, 132665],
#  'U1006': [132717, 132613, 135030, 132845, 132560],
#  'U1007': [132922, 135039, 132609],
#  'U1008': [135016],
#  'U1009': [135046, 132925, 132583, 135065, 132723],
#  'U1010': [135108, 135042, 132755, 132583, 135042],
#  'U1011': [132872, 132732, 135018, 135027, 132560],
#  'U1012': [135052, 132668],
#  'U1013': [135043],
#  'U1014': [132654, 135048, 132851, 135058, 135076],
#  'U1015': [132834, 135076, 135039, 135038],
#  'U1016': [135044, 132715, 135088],
#  'U1017': [135040, 134996, 135048, 135060, 132830],
#  'U1018': [135064, 135047, 132937, 135001, 135039],
#  'U1019': [132866],
#  'U1020': [135054, 135062],
#  'U1021': [134999, 132958],
#  'U1022': [132877, 135032, 135032],
#  'U1023': [132594, 135075],
#  'U1024': [135082, 135055, 135025],
#  'U1025': [135038, 135055, 132663, 135079],
# ...

# %%
data_items = records.items()
data_list = list(data_items)

df = pd.DataFrame(data_list)
df = df.rename(columns={0: 'userID', 1: 'placeID'})
df = df.explode('placeID')
df['purchaseID'] = np.arange(1000, 1413, 1)
df = df[['purchaseID', 'userID', 'placeID']]
df
# Out:
#      purchaseID userID placeID
# 0          1000  U1001  132862
# 0          1001  U1001  135062
# 1          1002  U1002  135069
# 1          1003  U1002  132872
# 1          1004  U1002  135026
# ..          ...    ...     ...
# 136        1408  U1137  132951
# 137        1409  U1138  135035
# 137        1410  U1138  135080
# 137        1411  U1138  132954
# 137        1412  U1138  132706
#
# [413 rows x 3 columns]

# %%
price = np.zeros(413)
for i in range(0, len(price)):
    price[i] = np.random.choice([10, 20, 30, 40, 50])
price
df['cost'] = price
df
# Out:
#      purchaseID userID placeID  cost
# 0          1000  U1001  132862  50.0
# 0          1001  U1001  135062  30.0
# 1          1002  U1002  135069  40.0
# 1          1003  U1002  132872  30.0
# 1          1004  U1002  135026  50.0
# ..          ...    ...     ...   ...
# 136        1408  U1137  132951  10.0
# 137        1409  U1138  135035  50.0
# 137        1410  U1138  135080  50.0
# 137        1411  U1138  132954  50.0
# 137        1412  U1138  132706  30.0
#
# [413 rows x 4 columns]

# %%
reviews = pd.read_csv(r"C:\Users\sohan\OneDrive\Desktop\reviews.csv")
reviews
reviews['reviewID'] = np.arange(1000, 2161, 1)
reviews
reviews.to_csv(path_or_buf = r"C:\Users\sohan\OneDrive\Desktop\reviews.csv")

# %%
groups = pd.read_csv(r"C:\Users\sohan\OneDrive\Desktop\groups.csv")
groups
# Out:
#    groupID                                            members       type  \
# 0        0  ['U1024', 'U1027', 'U1048', 'U1083', 'U1122', ...  undecided
# 1        1  ['U1009', 'U1021', 'U1030', 'U1038', 'U1052', ...     family
# 2        2  ['U1001', 'U1009', 'U1019', 'U1028', 'U1034', ...     family
# 3        3                        ['U1001', 'U1038', 'U1084']     family
# 4        4      ['U1001', 'U1028', 'U1053', 'U1081', 'U1113']     family
# 5        5  ['U1001', 'U1011', 'U1022', 'U1032', 'U1042', ...     family
# 6        6  ['U1006', 'U1018', 'U1040', 'U1059', 'U1070', ...    friends
# 7        7      ['U1006', 'U1039', 'U1065', 'U1101', 'U1118']    friends
# 8        8      ['U1006', 'U1041', 'U1080', 'U1112', 'U1136']    friends
# 9        9  ['U1006', 'U1014', 'U1020', 'U1039', 'U1045', ...    friends
#
#   min_budget cuisine_overlap
# 0        low          Afghan
# 1        low       Fast_Food
# 2        low        American
# 3        low        American
# ...

# %%
members = groups['members']
members[0]
# Out:
# "['U1024', 'U1027', 'U1048', 'U1083', 'U1122', 'U1130']"

# %%
from ast import literal_eval
mid_longitude = []
mid_latitude = []
literal_eval(members[0])
for i in members:
    latitudes = []
    longitudes = []
    for j in literal_eval(i):
        latitudes.append(float(Users.loc[Users['userID'] == j]['latitude']))
        longitudes.append(float(Users.loc[Users['userID'] == j]['longitude']))
    mid_longitude.append(sum(longitudes)/len(longitudes))
    mid_latitude.append(sum(latitudes)/len(latitudes))
mid_latitude
# Out:
# [22.416316666666663,
#  21.982639909090906,
#  22.038525999999997,
#  22.14610233333333,
#  22.4827592,
#  21.874691000000002,
#  21.074890444444446,
#  22.142536999999997,
#  21.824333799999998,
#  21.71941886666667]

# %%
groups['midLong'] = mid_longitude
groups['midLat'] = mid_latitude
groups
# Out:
#    groupID                                            members       type  \
# 0        0  ['U1024', 'U1027', 'U1048', 'U1083', 'U1122', ...  undecided
# 1        1  ['U1009', 'U1021', 'U1030', 'U1038', 'U1052', ...     family
# 2        2  ['U1001', 'U1009', 'U1019', 'U1028', 'U1034', ...     family
# 3        3                        ['U1001', 'U1038', 'U1084']     family
# 4        4      ['U1001', 'U1028', 'U1053', 'U1081', 'U1113']     family
# 5        5  ['U1001', 'U1011', 'U1022', 'U1032', 'U1042', ...     family
# 6        6  ['U1006', 'U1018', 'U1040', 'U1059', 'U1070', ...    friends
# 7        7      ['U1006', 'U1039', 'U1065', 'U1101', 'U1118']    friends
# 8        8      ['U1006', 'U1041', 'U1080', 'U1112', 'U1136']    friends
# 9        9  ['U1006', 'U1014', 'U1020', 'U1039', 'U1045', ...    friends
#
#   min_budget cuisine_overlap     midLong     midLat
# 0        low          Afghan -100.689837  22.416317
# 1        low       Fast_Food -100.147263  21.982640
# ...

# %%
groups.to_csv(r"C:\Users\sohan\OneDrive\Desktop\groups.csv")

# %%
groups = pd.read_csv(r"C:\Users\sohan\OneDrive\Desktop\groups.csv")

# %%
groups
# Out:
#    groupID                                            members       type  \
# 0        0  ['U1024', 'U1027', 'U1048', 'U1083', 'U1122', ...  undecided
# 1        1  ['U1009', 'U1021', 'U1030', 'U1038', 'U1052', ...     family
# 2        2  ['U1001', 'U1009', 'U1019', 'U1028', 'U1034', ...     family
# 3        3                        ['U1001', 'U1038', 'U1084']     family
# 4        4      ['U1001', 'U1028', 'U1053', 'U1081', 'U1113']     family
# 5        5  ['U1001', 'U1011', 'U1022', 'U1032', 'U1042', ...     family
# 6        6  ['U1006', 'U1018', 'U1040', 'U1059', 'U1070', ...    friends
# 7        7      ['U1006', 'U1039', 'U1065', 'U1101', 'U1118']    friends
# 8        8      ['U1006', 'U1041', 'U1080', 'U1112', 'U1136']    friends
# 9        9  ['U1006', 'U1014', 'U1020', 'U1039', 'U1045', ...    friends
#
#   min_budget cuisine_overlap     midLong     midLat
# 0        low          Afghan -100.689837  22.416317
# 1        low       Fast_Food -100.147263  21.982640
# ...

# %%
g = []
m = []
for i in groups['groupID']:
    for j in groups.loc[groups['groupID'] == i]['members']:
        for k in literal_eval(j):
            g.append(i)
            m.append(k)
groupMembers = pd.DataFrame({'groupID': g, 'userID': m})
groupMembers
# Out:
#     groupID userID
# 0         0  U1024
# 1         0  U1027
# 2         0  U1048
# 3         0  U1083
# 4         0  U1122
# ..      ...    ...
# 80        9  U1106
# 81        9  U1112
# 82        9  U1118
# 83        9  U1125
# 84        9  U1129
#
# [85 rows x 2 columns]

# %%
Users
# Out:
#      Unnamed: 0 userID   latitude   longitude smoker     drink_level  \
# 0             0  U1001  22.139997 -100.978803  false      abstemious
# 1             1  U1002  22.150087 -100.983325  false      abstemious
# 2             2  U1003  22.119847 -100.946527  false  social drinker
# 3             3  U1004  18.867000  -99.183000  false      abstemious
# 4             4  U1005  22.183477 -100.959891  false      abstemious
# ..          ...    ...        ...         ...    ...             ...
# 133         133  U1134  22.149654 -100.998610  false  casual drinker
# 134         134  U1135  22.170396 -100.949936  false  casual drinker
# 135         135  U1136  22.149607 -100.997235   true  social drinker
# 136         136  U1137  22.144803 -100.944623  false  social drinker
# 137         137  U1138  22.152884 -100.939663  false  social drinker
#
#     dress_preference ambience  transport marital_status  birth_year  \
# 0           informal   family    on foot         single        1989
# ...

# %%
u = []
c = []
for i in Users['userID']:
    for j in Users.loc[Users['userID'] == i]['Rcuisine']:
        for k in literal_eval(j):
            u.append(i)
            c.append(k)
userCuisines = pd.DataFrame({'userID': u, 'cuisine': c})
userCuisines
# Out:
#     userID            cuisine
# 0    U1001           American
# 1    U1002            Mexican
# 2    U1003            Mexican
# 3    U1004             Bakery
# 4    U1004   Breakfast-Brunch
# ..     ...                ...
# 325  U1135           Southern
# 326  U1135  Dessert-Ice_Cream
# 327  U1136            Mexican
# 328  U1137            Mexican
# 329  U1138           Pizzeria
#
# [330 rows x 2 columns]

# %%
Restaurants
# Out:
#      Unnamed: 0  placeID   latitude   longitude  \
# 0             0   134999  18.915421  -99.184871
# 1             1   132825  22.147392 -100.983092
# 2             2   135106  22.149709 -100.976093
# 3             3   132667  23.752697  -99.163359
# 4             4   132613  23.752903  -99.165076
# ..          ...      ...        ...         ...
# 125         125   132866  22.141220 -100.931311
# 126         126   135072  22.149192 -101.002936
# 127         127   135109  18.921785  -99.235350
# 128         128   135019  18.875011  -99.159422
# 129         129   132877  22.135364 -100.934948
#
#                                name  \
# 0                   Kiku Cuernavaca
# 1                   puesto de tacos
# 2        El Rincón de San Francisco
# 3    little pizza Emilio Portes Gil
# 4                     carnitas_mata
# ..                              ...
# 125                         Chaires
# 126                      Sushi Itto
# 127                       Paniroles
# ...

# %%
p = []
c = []
for i in Restaurants['placeID']:
    for j in Restaurants.loc[Restaurants['placeID'] == i]['Rcuisine']:
        for k in literal_eval(j):
            p.append(i)
            c.append(k)
resCuisines = pd.DataFrame({'userID': p, 'cuisine': c})
resCuisines
# Out:
#      userID    cuisine
# 0    134999   Japanese
# 1    132825    Mexican
# 2    135106    Mexican
# 3    132667   Armenian
# 4    132613    Mexican
# ..      ...        ...
# 142  132866  Cafeteria
# 143  135072   Japanese
# 144  135109    Italian
# 145  135019        Bar
# 146  132877    Mexican
#
# [147 rows x 2 columns]

# %%
resCuisines.to_csv(r"C:\Users\sohan\OneDrive\Desktop\resCuisines.csv")
userCuisines.to_csv(r"C:\Users\sohan\OneDrive\Desktop\userCuisines.csv")
groupMembers.to_csv(r"C:\Users\sohan\OneDrive\Desktop\groupMembers.csv")
